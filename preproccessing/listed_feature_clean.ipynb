# %%
import pandas as pd

# pd.set_option("display.max_seq_items", None)
pd.set_option('display.max_columns', None)

# %%
kskqkn = pd.read_csv('../1.데이터셋/Feature/상장피처ver1.csv')
kskqkn.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '총자본증가율(IFRS연결)', '유형자산증가율(IFRS연결)',
#        '비유동생물자산증가율(IFRS연결)', '투자부동산증가율(IFRS연결)', '비유동자산증가율(IFRS연결)',
#        '유동자산증가율(IFRS연결)', '재고자산증가율(IFRS연결)',
#        ...
#        'EV/EBITDA(배)', '부실판단', '기업수명주기', '매출채권회전률', '종업원수증가율', 'CROE',
#        '총자산증가율', '총자산회전율', '영업년수', '상장년수'],
#       dtype='object', length=163)

# %%
col_list = [
    "회사명",
    "거래소코드",
    "회계년도",
    ###### 현금흐름(4) ########
    "CASH FLOW 대 부채비율(IFRS연결)",
    "CASH FLOW 대 차입금비율(IFRS연결)",
    "CASH FLOW 대 총자본비율(IFRS연결)",
    "CASH FLOW 대 매출액비율(IFRS연결)",
    ###### 안정성(10) ########
    "유동비율(IFRS연결)",
    "당좌비율(IFRS연결)",
    "비유동비율(IFRS연결)",
    "부채비율(IFRS연결)",
    "유동부채비율(IFRS연결)",
    "차입금의존도(IFRS연결)",
    "순운전자본비율(IFRS연결)",
    "현금비율(IFRS연결)",
    "유동자산구성비율(IFRS연결)",
    "자기자본구성비율(IFRS연결)",
    ###### 수익성(10) ########
    "자기자본순이익률(IFRS연결)",
    "경영자본순이익률(IFRS연결)",
    "매출액순이익률(IFRS연결)",
    "매출액총이익률(IFRS연결)",
    "총자본사업이익률(IFRS연결)",
    "총자본정상영업이익률(IFRS연결)",
    "자기자본정상영업이익률(IFRS연결)",
    "매출액정상영업이익률(IFRS연결)",
    "금융비용부담률(IFRS연결)",
    "CROE",
    ###### 성장성(8) ########
    "총자산증가율",
    "총자본증가율(IFRS연결)",
    "유동자산증가율(IFRS연결)",
    "비유동자산증가율(IFRS연결)",
    "매출액증가율(IFRS연결)",
    "자기자본배율(IFRS연결)",
    "유형자산증가율(IFRS연결)",
    "재고자산증가율(IFRS연결)",
    ###### 생산성(5) ########
    "부가가치(IFRS연결)(백만원)",
    "총자본투자효율(IFRS연결)",
    "설비투자효율(IFRS연결)",
    "부가가치율(IFRS연결)",
    "이윤분배율(IFRS연결)",
	"자본분배율(IFRS연결)",
    ###### 활동성(10) ########
    "총자산회전율",
    "매출채권회전률",
    "당좌자산회전률(IFRS연결)",
    "유형자산회전율(IFRS연결)",
    "자기자본회전률(IFRS연결)",
    "경영자본회전률(IFRS연결)",
    "총자본회전률(IFRS연결)",
    "비유동자산회전률(IFRS연결)",
    "순운전자본회전률(IFRS연결)",
    "유동자산회전률(IFRS연결)",
    ###### 기타 ########
    "영업년수",
	"상장년수",
	"기업수명주기",
	'부실판단'
]

# %%
kskqkn = kskqkn[col_list]

# %%
kskqkn.columns = [
    "회사명",
    "거래소코드",
    "회계년도",
    ###### 현금흐름(4) ########
    "CASH FLOW 대 부채비율",
    "CASH FLOW 대 차입금비율",
    "CASH FLOW 대 총자본비율",
    "CASH FLOW 대 매출액비율",
    ###### 안정성(10) ########
    "유동비율",
    "당좌비율",
    "비유동비율",
    "부채비율",
    "유동부채비율",
    "차입금의존도",
    "순운전자본비율",
    "현금비율",
    "유동자산구성비율",
    "자기자본구성비율",
    ###### 수익성(10) ########
    "자기자본순이익률",
    "경영자본순이익률",
    "매출액순이익률",
    "매출액총이익률",
    "총자본사업이익률",
    "총자본정상영업이익률",
    "자기자본정상영업이익률",
    "매출액정상영업이익률",
    "금융비용부담률",
    "CROE",
    ###### 성장성(8) ########
    "총자산증가율",
    "총자본증가율",
    "유동자산증가율",
    "비유동자산증가율",
    "매출액증가율",
    "자기자본배율",
    "유형자산증가율",
    "재고자산증가율",
    ###### 생산성(5) ########
    "부가가치(백만원)",
    "총자본투자효율",
    "설비투자효율",
    "부가가치율",
    "이윤분배율",
    "자본분배율",
    ###### 활동성(10) ########
    "총자산회전율",
    "매출채권회전률",
    "당좌자산회전률",
    "유형자산회전율",
    "자기자본회전률",
    "경영자본회전률",
    "총자본회전률",
    "비유동자산회전률",
    "순운전자본회전률",
    "유동자산회전률",
    ###### 기타 ########
    "영업년수",
    "상장년수",
    "기업수명주기",
    "부실판단",
]

# %%
kskqkn["부실판단"].isna().sum()
# Out:
# 22

# %%
kskqkn = kskqkn.dropna(subset=['부실판단'], axis=0)

# %%
kskqkn["기업수명주기"].isna().sum()
# Out:
# 0

# %%
kskqkn = kskqkn.dropna(subset=["기업수명주기"], axis=0)

# %%
kskqkn
# Out:
#               회사명   거래소코드  회계년도  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0        (주)CMG제약   58820  2022                19                 79
# 1         (주)ES큐브   50120  2020                 3                270
# 2        (주)MH에탄올   23150  2022                 6                  9
# 3      (주)강스템바이오텍  217730  2017               -47                -75
# 4        (주)강원에너지  114190  2018               -16                -28
# ..            ...     ...   ...               ...                ...
# 884     에이펙스인텍(주)  207490  2022                 3                  4
# 885        위월드(주)  140660  2022                 0                  0
# 886  인바이츠바이오코아(주)  216400  2022                 4                  7
# 887       크로넥스(주)  215570  2017                 0                  0
# 888       태양기계(주)  116100  2022                27                  3
#
#      CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  유동비율  당좌비율  비유동비율  부채비율  유동부채비율  \
# ...

# %%
kskqkn.reset_index(drop=True).to_csv('../1.데이터셋/Feature/상장피처clean1.csv', index=False)

# %%
df = pd.read_csv('../1.데이터셋/Feature/상장피처clean1.csv')
df
# Out:
#               회사명   거래소코드  회계년도  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0        (주)CMG제약   58820  2022                19                 79
# 1         (주)ES큐브   50120  2020                 3                270
# 2        (주)MH에탄올   23150  2022                 6                  9
# 3      (주)강스템바이오텍  217730  2017               -47                -75
# 4        (주)강원에너지  114190  2018               -16                -28
# ..            ...     ...   ...               ...                ...
# 862     에이펙스인텍(주)  207490  2022                 3                  4
# 863        위월드(주)  140660  2022                 0                  0
# 864  인바이츠바이오코아(주)  216400  2022                 4                  7
# 865       크로넥스(주)  215570  2017                 0                  0
# 866       태양기계(주)  116100  2022                27                  3
#
#      CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  유동비율  당좌비율  비유동비율  부채비율  유동부채비율  \
# ...

# %%
col_list = [
    "회사명",
    "거래소코드",
    "회계년도",
    ###### 현금흐름(4) ########
    "CASH FLOW 대 부채비율",
    "CASH FLOW 대 차입금비율",
    "CASH FLOW 대 총자본비율",
    "CASH FLOW 대 매출액비율",
    ###### 안정성(10) ########
    "유동비율",
    "당좌비율",
    # "비유동비율",
    "부채비율",
    "유동부채비율",
    "차입금의존도",
    "순운전자본비율",
    "현금비율",
    "유동자산구성비율",
    "자기자본구성비율",
    ###### 수익성(10) ########
    "자기자본순이익률",
    "경영자본순이익률",
    "매출액순이익률",
    # "매출액총이익률",
    "총자본사업이익률",
    "총자본정상영업이익률",
    # "자기자본정상영업이익률",
    "매출액정상영업이익률",
    "금융비용부담률",
    "CROE",
    ###### 성장성(8) ########
    "총자산증가율",
    "총자본증가율",
    "유동자산증가율",
    "비유동자산증가율",
    "매출액증가율",
    # "자기자본배율",
    "유형자산증가율",
    # "재고자산증가율",
    ###### 생산성(5) ########
    "부가가치(백만원)",
    "총자본투자효율",
    "설비투자효율",
    "부가가치율",
    "이윤분배율",
	"자본분배율",
    ###### 활동성(10) ########
    "총자산회전율",
    "매출채권회전률",
    "당좌자산회전률",
    "유형자산회전율",
    # "자기자본회전률",
    "경영자본회전률",
    "총자본회전률",
    "비유동자산회전률",
    # "순운전자본회전률",
    "유동자산회전률",
    ###### 기타 ########
    "영업년수",
    "상장년수",
    "기업수명주기",
    "부실판단",
]

# %%
kskqkn_clean = df[col_list]

# %%
kskqkn_clean.to_csv('../1.데이터셋/Feature/상장피처clean2.csv', index=False)
