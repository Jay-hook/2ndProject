# %%
import pandas as pd

# %%
audit = pd.read_csv('../1.데이터셋/Feature/비상장피처clean1.csv')
audit.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 차입금비율',
#        'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '유동비율', '당좌비율', '부채비율',
#        '유동부채비율', '차입금의존도', '순운전자본비율', '현금비율', '유동자산구성비율', '자기자본구성비율',
#        '자기자본순이익률', '경영자본순이익률', '매출액순이익률', '총자본사업이익률', '총자본영업이익률', '매출액영업이익률',
#        '금융비용부담률', 'CROE', '총자산증가율', '총자본증가율', '유동자산증가율', '비유동자산증가율', '매출액증가율',
#        '유형자산증가율', '부가가치(백만원)', '총자본투자효율', '설비투자효율', '부가가치율', '이윤분배율', '자본분배율',
#        '총자산회전율', '매출채권회전률', '당좌자산회전률', '유형자산회전율', '경영자본회전률', '총자본회전률',
#        '비유동자산회전률', '유동자산회전률', '설립일', '기업수명주기', '부실판단', '영업년수'],
#       dtype='object')

# %%
audit = audit.drop(['설립일'], axis=1)

# %%
audit = audit[
    [
        "회사명",
        "거래소코드",
        "회계년도",
        "CASH FLOW 대 부채비율",
        "CASH FLOW 대 차입금비율",
        "CASH FLOW 대 총자본비율",
        "CASH FLOW 대 매출액비율",
        "유동비율",
        "당좌비율",
        "부채비율",
        "유동부채비율",
        "차입금의존도",
        "순운전자본비율",
        "현금비율",
        "유동자산구성비율",
        "자기자본구성비율",
        "자기자본순이익률",
        "경영자본순이익률",
        "매출액순이익률",
        "총자본사업이익률",
        "총자본영업이익률",
        "매출액영업이익률",
        "금융비용부담률",
        "CROE",
        "총자산증가율",
        "총자본증가율",
        "유동자산증가율",
        "비유동자산증가율",
        "매출액증가율",
        "유형자산증가율",
        "부가가치(백만원)",
        "총자본투자효율",
        "설비투자효율",
        "부가가치율",
        "이윤분배율",
		"자본분배율",
        "총자산회전율",
        "매출채권회전률",
        "당좌자산회전률",
        "유형자산회전율",
        "경영자본회전률",
        "총자본회전률",
        "비유동자산회전률",
        "유동자산회전률",
        "영업년수",
        "기업수명주기",
        "부실판단",
    ]
]

# %%
# 각 행의 0의 개수를 계산하여 'zero_count' 열에 저장
audit["zero_count"] = audit.apply(lambda row: row.value_counts().get(0, 0), axis=1)

# %%
audit['zero_count'].quantile(0.8)
# Out:
# 5.0

# %%
audit = audit[audit['zero_count'] <= 5]

# %%
audit = audit.drop(['zero_count'], axis=1)

# %%
# get_dummies() 함수를 사용하여 '기업수명주기' 열을 더미 변수로 변환
df_dummy = pd.get_dummies(audit["기업수명주기"], prefix="기업수명주기")

# 데이터프레임에 더미 변수 추가
audit = pd.concat([audit, df_dummy], axis=1)

# # '기업수명주기' 열을 정수형으로 변환 (0 또는 1)
# audit["기업수명주기"] = audit["기업수명주기"].astype(int)

# '기업수명주기' 열을 더미 변수로 변환하기 전 열 제거
audit.drop(columns=["기업수명주기"], axis=1, inplace=True, errors="ignore")

# %%
# '기업수명주기' 열을 정수형으로 변환 (0 또는 1)
audit[["기업수명주기_도입기", "기업수명주기_성숙기", "기업수명주기_성장기", "기업수명주기_쇠퇴기"]] = audit[["기업수명주기_도입기", "기업수명주기_성숙기", "기업수명주기_성장기", "기업수명주기_쇠퇴기"]].astype(int)

# %%
audit.rename(
    columns={
        "기업수명주기_도입기": "도입기",
        "기업수명주기_성숙기": "성숙기",
        "기업수명주기_성장기": "성장기",
        "기업수명주기_쇠퇴기": "쇠퇴기",
    }, inplace=True
)

# %%
audit
# Out:
#             회사명  거래소코드  회계년도  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0        주식회사성환  81567  2019              7.09              17.07
# 1        주식회사성후  86355  2022              8.06              22.99
# 2        주식회사성훈  94984  2021             -0.66              -0.69
# 3      주식회사성훈철강  56923  2022             23.22              30.13
# 4        주식회사성희  63893  2021            -11.77             -12.62
# ...         ...    ...   ...               ...                ...
# 24762  주식회사나노브릭  77738  2017            -14.23             -27.59
# 24764   주식회사나노아  67623  2017           -153.85               0.00
# 24765  주식회사나노앤텍  72817  2022              0.76               0.85
# 24766   주식회사나노코  56825  2022             28.06              38.70
# 24767   주식회사나노팜  29937  2019             29.25               0.00
#
#        CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율    유동비율    당좌비율     부채비율  ...  \
# 0                   0.56              13.70   30.42   30.42     8.61  ...
# 1                   5.92              80.12  211.53  211.53   276.77  ...
# 2                  -0.68             -13.77    9.30    9.23     0.00  ...
# 3                   7.23              12.35   65.24   50.34    45.27  ...
# 4                  -8.05           -1202.08  141.01    3.01   216.01  ...
# ...                  ...                ...     ...     ...      ...  ...
# 24762             -13.90             -41.83   20.67    9.69  4278.15  ...
# 24764             -49.38            -934.36  313.18  313.18    47.27  ...
# 24765               0.57               1.40   63.52   34.19   304.84  ...
# 24766              11.23              11.22  261.67  184.98    66.72  ...
# 24767               6.52              10.65  763.56  526.40    28.67  ...
#
#        경영자본회전률  총자본회전률  비유동자산회전률  유동자산회전률  영업년수  부실판단  도입기  성숙기  성장기  쇠퇴기
# 0         0.04    0.04      0.04     4.05   8.0   0.0    0    1    0    0
# 1         0.08    0.08      0.09     2.34   7.0   0.0    0    0    1    0
# 2         0.05    0.05      0.05     1.25   5.0   1.0    1    0    0    0
# 3         1.14    0.61      0.73     3.57  29.0   0.0    0    1    0    0
# 4         0.01    0.01      0.08     0.01  20.0   1.0    0    0    0    1
# ...        ...     ...       ...      ...   ...   ...  ...  ...  ...  ...
# 24762     0.31    0.29      0.33     2.08  17.0   1.0    0    0    0    1
# 24764     0.02    0.02      0.02     0.10  14.0   0.0    0    0    0    1
# 24765     0.52    0.50      0.63     2.46  19.0   0.0    0    0    1    0
# 24766     1.12    1.01      2.48     1.70  24.0   0.0    0    1    0    0
# 24767     0.65    0.63      1.80     0.96  26.0   0.0    0    1    0    0
#
# [20707 rows x 50 columns]

# %%
audit.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 차입금비율',
#        'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '유동비율', '당좌비율', '부채비율',
#        '유동부채비율', '차입금의존도', '순운전자본비율', '현금비율', '유동자산구성비율', '자기자본구성비율',
#        '자기자본순이익률', '경영자본순이익률', '매출액순이익률', '총자본사업이익률', '총자본영업이익률', '매출액영업이익률',
#        '금융비용부담률', 'CROE', '총자산증가율', '총자본증가율', '유동자산증가율', '비유동자산증가율', '매출액증가율',
#        '유형자산증가율', '부가가치(백만원)', '총자본투자효율', '설비투자효율', '부가가치율', '이윤분배율', '자본분배율',
#        '총자산회전율', '매출채권회전률', '당좌자산회전률', '유형자산회전율', '경영자본회전률', '총자본회전률',
#        '비유동자산회전률', '유동자산회전률', '영업년수', '부실판단', '도입기', '성숙기', '성장기', '쇠퇴기'],
#       dtype='object')

# %%
audit[
    [
        "회사명",
        "거래소코드",
        "회계년도",
        "CASH FLOW 대 부채비율",
        "CASH FLOW 대 차입금비율",
        "CASH FLOW 대 총자본비율",
        "CASH FLOW 대 매출액비율",
        "유동비율",
        "당좌비율",
        "부채비율",
        "유동부채비율",
        "차입금의존도",
        "순운전자본비율",
        "현금비율",
        "유동자산구성비율",
        "자기자본구성비율",
        "자기자본순이익률",
        "경영자본순이익률",
        "매출액순이익률",
        "총자본사업이익률",
        "총자본영업이익률",
        "매출액영업이익률",
        "금융비용부담률",
        "CROE",
        "총자산증가율",
        "총자본증가율",
        "유동자산증가율",
        "비유동자산증가율",
        "매출액증가율",
        "유형자산증가율",
        "부가가치(백만원)",
        "총자본투자효율",
        "설비투자효율",
        "부가가치율",
        "이윤분배율",
        "자본분배율",
        "총자산회전율",
        "매출채권회전률",
        "당좌자산회전률",
        "유형자산회전율",
        "경영자본회전률",
        "총자본회전률",
        "비유동자산회전률",
        "유동자산회전률",
        "영업년수",
        "도입기",
        "성숙기",
        "성장기",
        "쇠퇴기",
        "부실판단",
    ]
]
# Out:
#             회사명  거래소코드  회계년도  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0        주식회사성환  81567  2019              7.09              17.07
# 1        주식회사성후  86355  2022              8.06              22.99
# 2        주식회사성훈  94984  2021             -0.66              -0.69
# 3      주식회사성훈철강  56923  2022             23.22              30.13
# 4        주식회사성희  63893  2021            -11.77             -12.62
# ...         ...    ...   ...               ...                ...
# 24762  주식회사나노브릭  77738  2017            -14.23             -27.59
# 24764   주식회사나노아  67623  2017           -153.85               0.00
# 24765  주식회사나노앤텍  72817  2022              0.76               0.85
# 24766   주식회사나노코  56825  2022             28.06              38.70
# 24767   주식회사나노팜  29937  2019             29.25               0.00
#
#        CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율    유동비율    당좌비율     부채비율  ...  \
# 0                   0.56              13.70   30.42   30.42     8.61  ...
# 1                   5.92              80.12  211.53  211.53   276.77  ...
# 2                  -0.68             -13.77    9.30    9.23     0.00  ...
# 3                   7.23              12.35   65.24   50.34    45.27  ...
# 4                  -8.05           -1202.08  141.01    3.01   216.01  ...
# ...                  ...                ...     ...     ...      ...  ...
# 24762             -13.90             -41.83   20.67    9.69  4278.15  ...
# 24764             -49.38            -934.36  313.18  313.18    47.27  ...
# 24765               0.57               1.40   63.52   34.19   304.84  ...
# 24766              11.23              11.22  261.67  184.98    66.72  ...
# 24767               6.52              10.65  763.56  526.40    28.67  ...
#
#        경영자본회전률  총자본회전률  비유동자산회전률  유동자산회전률  영업년수  도입기  성숙기  성장기  쇠퇴기  부실판단
# 0         0.04    0.04      0.04     4.05   8.0    0    1    0    0   0.0
# 1         0.08    0.08      0.09     2.34   7.0    0    0    1    0   0.0
# 2         0.05    0.05      0.05     1.25   5.0    1    0    0    0   1.0
# 3         1.14    0.61      0.73     3.57  29.0    0    1    0    0   0.0
# 4         0.01    0.01      0.08     0.01  20.0    0    0    0    1   1.0
# ...        ...     ...       ...      ...   ...  ...  ...  ...  ...   ...
# 24762     0.31    0.29      0.33     2.08  17.0    0    0    0    1   1.0
# 24764     0.02    0.02      0.02     0.10  14.0    0    0    0    1   0.0
# 24765     0.52    0.50      0.63     2.46  19.0    0    0    1    0   0.0
# 24766     1.12    1.01      2.48     1.70  24.0    0    1    0    0   0.0
# 24767     0.65    0.63      1.80     0.96  26.0    0    1    0    0   0.0
#
# [20707 rows x 50 columns]

# %%
audit.isna().sum()
# Out:
# 회사명                     0
# 거래소코드                   0
# 회계년도                    0
# CASH FLOW 대 부채비율        0
# CASH FLOW 대 차입금비율       0
# CASH FLOW 대 총자본비율       0
# CASH FLOW 대 매출액비율       0
# 유동비율                    0
# 당좌비율                    0
# 부채비율                    0
# 유동부채비율                  0
# 차입금의존도                  0
# 순운전자본비율                 0
# 현금비율                    0
# 유동자산구성비율                0
# 자기자본구성비율                0
# 자기자본순이익률                1
# 경영자본순이익률                1
# 매출액순이익률                 1
# 총자본사업이익률                1
# 총자본영업이익률                1
# 매출액영업이익률                1
# 금융비용부담률                 1
# CROE                 1855
# 총자산증가율               1854
# 총자본증가율                  0
# 유동자산증가율                 0
# 비유동자산증가율                0
# 매출액증가율                  0
# 유형자산증가율                 0
# 부가가치(백만원)               1
# 총자본투자효율                 1
# 설비투자효율                  1
# 부가가치율                   1
# 이윤분배율                   1
# 자본분배율                   1
# 총자산회전율               1855
# 매출채권회전률                 0
# 당좌자산회전률                 0
# 유형자산회전율                 0
# 경영자본회전률                 0
# 총자본회전률                  0
# 비유동자산회전률                0
# 유동자산회전률                 0
# 영업년수                   21
# 부실판단                    0
# 도입기                     0
# 성숙기                     0
# 성장기                     0
# 쇠퇴기                     0
# dtype: int64

# %%
audit = audit.fillna(0)

# %%
audit.reset_index(drop=True).to_csv('../1.데이터셋/Feature/후보피처/비상장후보피처.csv', index=False)
