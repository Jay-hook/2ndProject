# %% [markdown]
# 목표 : 파생변수 Derived Variable 만들기
# ========
# - 법인세 변화율
# - 영업레버리지 = 매출총이익 / 영업이익
# - 재무레버리지 = 영업이익 / 세전이익

# %% [markdown]
# load modules

# %%
import pandas as pd
import numpy as np
import platform

#워닝 메시지
import warnings
warnings.filterwarnings('ignore')

import os
current_directory = os.getcwd()
print("현재 디렉토리:", current_directory)
# Out:
# 현재 디렉토리: c:\Users\LG\2ndProject\1_데이터 수집 및 전처리

# %% [markdown]
# 환경설정

# %%
# pd.set_option('display.max_rows', None)
pd.reset_option('display.max_rows')

# pd.set_option('display.max_columns', None)
pd.reset_option('display.max_columns')

pd.set_option('display.max_seq_items', None)

pd.set_option('float_format', '{:.3f}'.format) # 소수점 3개까지 출력

# %% [markdown]
# read csv files

# %%
konex = pd.read_csv('../data/for_derived_variable/KONEX_손익들.csv', encoding='cp949')
kospi_kosdaq = pd.read_csv('../data/for_derived_variable/KOSPI_KOSDAQ_손익들.csv', encoding='cp949')

# %%
kospi_kosdaq.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[U01B100000000]매출액(수익)(*)(IFRS연결)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS연결)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS연결)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)',
#        '[U01B750000000]법인세비용(IFRS연결)(천원)',
#        '[U01B100000000]매출액(수익)(*)(IFRS)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)',
#        '[U01B750000000]법인세비용(IFRS)(천원)', '[U01210000]매출액(영업수익)(*)(연결)(천원)',
#        '[U01220010]매출원가(*)(연결)(천원)', '[U01221340]매출총이익(손실)(연결)(천원)',
#        '[U01222170]판매비와관리비(영업비용)(*)(연결)(천원)', '[U01230000]영업이익(손실)(연결)(천원)',
#        '[U01290000]법인세비용차감전(계속사업)손익(연결)(천원)',
# ...

# %%
konex.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[U01B100000000]매출액(수익)(*)(IFRS연결)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS연결)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS연결)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)',
#        '[U01B750000000]법인세비용(IFRS연결)(천원)',
#        '[U01B100000000]매출액(수익)(*)(IFRS)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)',
#        '[U01B750000000]법인세비용(IFRS)(천원)', '[U01210000]매출액(영업수익)(*)(연결)(천원)',
#        '[U01220010]매출원가(*)(연결)(천원)', '[U01221340]매출총이익(손실)(연결)(천원)',
#        '[U01222170]판매비와관리비(영업비용)(*)(연결)(천원)', '[U01230000]영업이익(손실)(연결)(천원)',
#        '[U01290000]법인세비용차감전(계속사업)손익(연결)(천원)',
# ...

# %%
상장재무 = pd.concat([konex, kospi_kosdaq], axis=0, ignore_index=True)

# %% [markdown]
# # 상장

# %% [markdown]
# ## describe

# %% [markdown]
# 상장재무

# %%
상장재무
# Out:
#           회사명   거래소코드     회계년도  [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)  \
# 0       (주)굿센  243870  2016/12                                    NaN
# 1       (주)굿센  243870  2017/12                                    NaN
# 2       (주)굿센  243870  2018/12                                    NaN
# 3       (주)굿센  243870  2019/12                                    NaN
# 4       (주)굿센  243870  2020/12                                    NaN
# ...       ...     ...      ...                                    ...
# 8657  휴마시스(주)  205470  2018/12                                    NaN
# 8658  휴마시스(주)  205470  2019/12                                    NaN
# 8659  휴마시스(주)  205470  2020/12                           45717212.000
# 8660  휴마시스(주)  205470  2021/12                          321829141.000
# 8661  휴마시스(주)  205470  2022/12                          471272761.000
#
#       [U01B200000000]매출원가(*)(IFRS연결)(천원)  \
# 0                                    NaN
# ...

# %%
상장재무.describe()
# Out:
#            거래소코드  [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)  \
# count   8662.000                               5833.000
# mean  128435.927                           70438449.893
# std   126761.458                           93645297.763
# min       40.000                                  0.000
# 25%    45520.000                           27313009.000
# 50%    91580.000                           50073204.000
# 75%   199290.000                           85313471.000
# max   950220.000                         2932001440.000
#
#        [U01B200000000]매출원가(*)(IFRS연결)(천원)  \
# count                            5833.000
# mean                         51776401.280
# std                          69886408.084
# min                                 0.000
# 25%                          16985797.000
# 50%                          35402377.000
# 75%                          63656866.000
# max                        1539006778.000
#
#        [U01B201014400]매출총이익(손실)(IFRS연결)(천원)  \
# ...

# %%
상장재무.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[U01B100000000]매출액(수익)(*)(IFRS연결)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS연결)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS연결)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)',
#        '[U01B750000000]법인세비용(IFRS연결)(천원)',
#        '[U01B100000000]매출액(수익)(*)(IFRS)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)',
#        '[U01B750000000]법인세비용(IFRS)(천원)', '[U01210000]매출액(영업수익)(*)(연결)(천원)',
#        '[U01220010]매출원가(*)(연결)(천원)', '[U01221340]매출총이익(손실)(연결)(천원)',
#        '[U01222170]판매비와관리비(영업비용)(*)(연결)(천원)', '[U01230000]영업이익(손실)(연결)(천원)',
#        '[U01290000]법인세비용차감전(계속사업)손익(연결)(천원)',
# ...

# %%
len(비상재무.columns)
# Out:
# 31

# %%
상장재무.isnull().sum().sort_values(ascending=False) / len(상장재무) * 100
# Out:
# [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)          32.660
# [U01B200000000]매출원가(*)(IFRS연결)(천원)             32.660
# [U01B201014400]매출총이익(손실)(IFRS연결)(천원)           32.660
# [U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)   32.660
# [U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)    32.660
# [U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)     32.660
# [U01B750000000]법인세비용(IFRS연결)(천원)               32.660
# [U01290100](계속사업손익)법인세비용(연결)(천원)               32.429
# [U01290000]법인세비용차감전(계속사업)손익(연결)(천원)            32.429
# [U01230000]영업이익(손실)(연결)(천원)                    32.429
# [U01222170]판매비와관리비(영업비용)(*)(연결)(천원)            32.429
# [U01221340]매출총이익(손실)(연결)(천원)                   32.429
# [U01220010]매출원가(*)(연결)(천원)                     32.429
# [U01210000]매출액(영업수익)(*)(연결)(천원)                32.429
# [U01290100](계속사업손익)법인세비용(천원)                    9.767
# [U01B750000000]법인세비용(IFRS)(천원)                  6.592
# [U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)        6.592
# ...

# %%
상장재무.isin([0]).sum().sort_values(ascending=False)
# Out:
# [U01B750000000]법인세비용(IFRS)(천원)                  1451
# [U01290100](계속사업손익)법인세비용(천원)                    1375
# [U01290100](계속사업손익)법인세비용(연결)(천원)                 565
# [U01B750000000]법인세비용(IFRS연결)(천원)                 557
# [U01220010]매출원가(*)(천원)                           486
# [U01B200000000]매출원가(*)(IFRS)(천원)                 470
# [U01220010]매출원가(*)(연결)(천원)                       345
# [U01B200000000]매출원가(*)(IFRS연결)(천원)               342
# [U01221340]매출총이익(손실)(천원)                          40
# [U01210000]매출액(영업수익)(*)(천원)                       39
# [U01B100000000]매출액(수익)(*)(IFRS)(천원)               26
# [U01B201014400]매출총이익(손실)(IFRS)(천원)                26
# [U01210000]매출액(영업수익)(*)(연결)(천원)                   12
# [U01221340]매출총이익(손실)(연결)(천원)                      12
# [U01B201014400]매출총이익(손실)(IFRS연결)(천원)               9
# [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)              9
# [U01290000]법인세비용차감전(계속사업)손익(연결)(천원)                3
# [U01222170]판매비와관리비(영업비용)(*)(연결)(천원)                3
# ...

# %%
상장재무.isin([np.inf]).sum().sort_values(ascending=False)
# Out:
# 회사명                                             0
# [U01B750000000]법인세비용(IFRS)(천원)                  0
# [U01290000]법인세비용차감전(계속사업)손익(천원)                 0
# [U01230000]영업이익(손실)(천원)                         0
# [U01222170]판매비와관리비(영업비용)(*)(천원)                 0
# [U01221340]매출총이익(손실)(천원)                        0
# [U01220010]매출원가(*)(천원)                          0
# [U01210000]매출액(영업수익)(*)(천원)                     0
# [U01290100](계속사업손익)법인세비용(연결)(천원)                0
# [U01290000]법인세비용차감전(계속사업)손익(연결)(천원)             0
# [U01230000]영업이익(손실)(연결)(천원)                     0
# [U01222170]판매비와관리비(영업비용)(*)(연결)(천원)             0
# [U01221340]매출총이익(손실)(연결)(천원)                    0
# [U01220010]매출원가(*)(연결)(천원)                      0
# [U01210000]매출액(영업수익)(*)(연결)(천원)                 0
# [U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)        0
# 거래소코드                                           0
# [U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)       0
# [U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)      0
# ...

# %%
len(상장재무.index)
# Out:
# 8662

# %% [markdown]
# 전처리?

# %%
상장재무.replace(0, np.nan, inplace=True)

# %% [markdown]
# ## 상장재무

# %%
상장재무
# Out:
#           회사명   거래소코드     회계년도  [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)  \
# 0       (주)굿센  243870  2016/12                                    NaN
# 1       (주)굿센  243870  2017/12                                    NaN
# 2       (주)굿센  243870  2018/12                                    NaN
# 3       (주)굿센  243870  2019/12                                    NaN
# 4       (주)굿센  243870  2020/12                                    NaN
# ...       ...     ...      ...                                    ...
# 8657  휴마시스(주)  205470  2018/12                                    NaN
# 8658  휴마시스(주)  205470  2019/12                                    NaN
# 8659  휴마시스(주)  205470  2020/12                           45717212.000
# 8660  휴마시스(주)  205470  2021/12                          321829141.000
# 8661  휴마시스(주)  205470  2022/12                          471272761.000
#
#       [U01B200000000]매출원가(*)(IFRS연결)(천원)  \
# 0                                    NaN
# ...

# %% [markdown]
# - 법인세 변화율 log_diff

# %% [markdown]
# 상장법인세

# %%
상장재무.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[U01B100000000]매출액(수익)(*)(IFRS연결)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS연결)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS연결)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)',
#        '[U01B750000000]법인세비용(IFRS연결)(천원)',
#        '[U01B100000000]매출액(수익)(*)(IFRS)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)',
#        '[U01B750000000]법인세비용(IFRS)(천원)', '[U01210000]매출액(영업수익)(*)(연결)(천원)',
#        '[U01220010]매출원가(*)(연결)(천원)', '[U01221340]매출총이익(손실)(연결)(천원)',
#        '[U01222170]판매비와관리비(영업비용)(*)(연결)(천원)', '[U01230000]영업이익(손실)(연결)(천원)',
#        '[U01290000]법인세비용차감전(계속사업)손익(연결)(천원)',
# ...

# %%
상장재무['log_diff'] = pd.Series(dtype=float)  # Creating an empty Series to store log_diff values

for i in range(1, len(상장재무.index)):
    if 상장재무['거래소코드'].loc[i] == 상장재무['거래소코드'].loc[i - 1]:
        상장재무['log_diff'].loc[i] = np.log(상장재무['[U01B750000000]법인세비용(IFRS연결)(천원)'].loc[i]) - np.log(상장재무['[U01B750000000]법인세비용(IFRS연결)(천원)'].loc[i - 1])
    else:
        상장재무['log_diff'].loc[i] = np.nan

# %%
상장재무['log_diff2'] = pd.Series(dtype=float)  # Creating an empty Series to store log_diff values

for i in range(1, len(상장재무.index)):
    if 상장재무['거래소코드'].loc[i] == 상장재무['거래소코드'].loc[i - 1]:
        상장재무['log_diff2'].loc[i] = np.log(상장재무['[U01B750000000]법인세비용(IFRS)(천원)'].loc[i]) - np.log(상장재무['[U01B750000000]법인세비용(IFRS)(천원)'].loc[i - 1])
    else:
        상장재무['log_diff2'].loc[i] = np.nan

# %%
상장재무['log_diff3'] = pd.Series(dtype=float)  # Creating an empty Series to store log_diff values

for i in range(1, len(상장재무.index)):
    if 상장재무['거래소코드'].loc[i] == 상장재무['거래소코드'].loc[i - 1]:
        상장재무['log_diff3'].loc[i] = np.log(상장재무['[U01290100](계속사업손익)법인세비용(연결)(천원)'].loc[i]) - np.log(상장재무['[U01290100](계속사업손익)법인세비용(연결)(천원)'].loc[i - 1])
    else:
        상장재무['log_diff3'].loc[i] = np.nan

# %%
상장재무['log_diff4'] = pd.Series(dtype=float)  # Creating an empty Series to store log_diff values

for i in range(1, len(상장재무.index)):
    if 상장재무['거래소코드'].loc[i] == 상장재무['거래소코드'].loc[i - 1]:
        상장재무['log_diff4'].loc[i] = np.log(상장재무['[U01290100](계속사업손익)법인세비용(천원)'].loc[i]) - np.log(상장재무['[U01290100](계속사업손익)법인세비용(천원)'].loc[i - 1])
    else:
        상장재무['log_diff4'].loc[i] = np.nan

# %%
상장재무['log_diff'].fillna(상장재무['log_diff2']).fillna(상장재무['log_diff3']).fillna(상장재무['log_diff4'], inplace=True)
상장재무.drop(
    labels=[
        '[U01B750000000]법인세비용(IFRS연결)(천원)',
        '[U01B750000000]법인세비용(IFRS)(천원)',
        '[U01290100](계속사업손익)법인세비용(연결)(천원)',
        '[U01290100](계속사업손익)법인세비용(천원)',
        'log_diff2', 'log_diff3', 'log_diff4'
    ],
    axis=1,
    inplace=True
)

# %%
상장재무.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[U01B100000000]매출액(수익)(*)(IFRS연결)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS연결)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS연결)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)',
#        '[U01B100000000]매출액(수익)(*)(IFRS)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)',
#        '[U01210000]매출액(영업수익)(*)(연결)(천원)', '[U01220010]매출원가(*)(연결)(천원)',
#        '[U01221340]매출총이익(손실)(연결)(천원)', '[U01222170]판매비와관리비(영업비용)(*)(연결)(천원)',
#        '[U01230000]영업이익(손실)(연결)(천원)', '[U01290000]법인세비용차감전(계속사업)손익(연결)(천원)',
#        '[U01210000]매출액(영업수익)(*)(천원)', '[U01220010]매출원가(*)(천원)',
# ...

# %%
상장재무['log_diff'].isna().sum() / len(상장재무['log_diff'])
# Out:
# 0.7365504502424383

# %% [markdown]
# - 영업레버리지 = 매출총이익 / 영업이익

# %%
상장국제연결영업이익 = 상장재무['[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)'].fillna(상장재무['[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)'])
상장국제연결영업레버리지 = 상장재무['[U01B201014400]매출총이익(손실)(IFRS연결)(천원)'] / 상장국제연결영업이익
상장국제개별영업이익 = 상장재무['[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)'].fillna(상장재무['[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)'])
상장국제개별영업레버리지 = 상장재무['[U01B201014400]매출총이익(손실)(IFRS)(천원)'] / 상장국제개별영업이익
상장일반연결영업이익 = 상장재무['[U01230000]영업이익(손실)(연결)(천원)']
상장일반연결영업레버리지 = 상장재무['[U01221340]매출총이익(손실)(연결)(천원)'] / 상장일반연결영업이익
상장일반개별영업이익 = 상장재무['[U01230000]영업이익(손실)(천원)']
상장일반개별영업레버리지 = 상장재무['[U01221340]매출총이익(손실)(천원)'] / 상장일반개별영업이익
상장영업레버리지 = 상장국제연결영업레버리지.fillna(상장국제개별영업레버리지)
상장영업레버리지 = 상장영업레버리지.fillna(상장일반연결영업레버리지)
상장영업레버리지 = 상장영업레버리지.fillna(상장일반개별영업레버리지)

# %%
상장재무['영업레버리지'] = 상장영업레버리지

# %%
# 상장매출총이익 = 상장재무['[U01B201014400]매출총이익(손실)(IFRS연결)(천원)'].fillna(상장재무['[U01B201014400]매출총이익(손실)(IFRS)(천원)'])
# 상장매출총이익 = 상장매출총이익.fillna(상장재무['[U01221340]매출총이익(손실)(연결)(천원)'])
# 상장매출총이익 = 상장매출총이익.fillna(상장재무['[U01221340]매출총이익(손실)(천원)'])
# 상장매출총이익 = 상장매출총이익.fillna(상장재무['상장매출액'] - 상장재무['상장매출원가'])
# 상장재무['상장매출총이익'] = 상장매출총이익
상장재무.drop(
    labels=
    [
        '[U01B201014400]매출총이익(손실)(IFRS연결)(천원)',
        '[U01B201014400]매출총이익(손실)(IFRS)(천원)',
        '[U01221340]매출총이익(손실)(연결)(천원)',
        '[U01221340]매출총이익(손실)(천원)',
        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)',
        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)',
        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)',
        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)',
        '[U01230000]영업이익(손실)(연결)(천원)',
        '[U01230000]영업이익(손실)(천원)'
    ],
    axis=1,
    inplace=True
)
# print(상장매출총이익.isna().value_counts())
# 상장재무['상장매출총이익'].describe()

# %% [markdown]
# - 재무레버리지 = 영업이익 / 세전이익

# %%
상장국제연결재무레버리지 = 상장국제연결영업이익 / 상장재무['[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)']
상장국제개별재무레버리지 = 상장국제개별영업이익 / 상장재무['[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)']
상장일반연결재무레버리지 = 상장일반연결영업이익 / 상장재무['[U01290000]법인세비용차감전(계속사업)손익(연결)(천원)']
상장일반개별재무레버리지 = 상장일반개별영업이익 / 상장재무['[U01290000]법인세비용차감전(계속사업)손익(천원)']
상장재무레버리지 = 상장국제연결재무레버리지.fillna(상장국제개별재무레버리지)
상장재무레버리지 = 상장재무레버리지.fillna(상장일반연결재무레버리지)
상장재무레버리지 = 상장재무레버리지.fillna(상장일반개별재무레버리지)
상장재무['재무레버리지'] = 상장재무레버리지

# %%
상장재무.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[U01B100000000]매출액(수익)(*)(IFRS연결)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS연결)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)',
#        '[U01B100000000]매출액(수익)(*)(IFRS)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)',
#        '[U01210000]매출액(영업수익)(*)(연결)(천원)', '[U01220010]매출원가(*)(연결)(천원)',
#        '[U01222170]판매비와관리비(영업비용)(*)(연결)(천원)',
#        '[U01290000]법인세비용차감전(계속사업)손익(연결)(천원)', '[U01210000]매출액(영업수익)(*)(천원)',
#        '[U01220010]매출원가(*)(천원)', '[U01222170]판매비와관리비(영업비용)(*)(천원)',
#        '[U01290000]법인세비용차감전(계속사업)손익(천원)', 'log_diff', '영업레버리지', '재무레버리지'],
#       dtype='object')

# %% [markdown]
# ## to_csv

# %%
상장재무 = 상장재무[['회사명', '거래소코드', '회계년도', 'log_diff', '영업레버리지', '재무레버리지']]

# %%
상장재무.isin([np.inf]).sum().sort_values(ascending=False)
# .index[0]
# Out:
# 회사명         0
# 거래소코드       0
# 회계년도        0
# log_diff    0
# 영업레버리지      0
# 재무레버리지      0
# dtype: int64

# %%
상장재무['log_diff'].value_counts().sort_index(ascending=False)
# Out:
# log_diff
# 9.159     1
# 7.929     1
# 7.917     1
# 7.523     1
# 7.094     1
#          ..
# -6.244    1
# -6.518    1
# -7.536    1
# -7.975    1
# -9.919    1
# Name: count, Length: 2282, dtype: int64

# %%
# inf_col = 상장재무.isin([np.inf]).sum().sort_values(ascending=False).index[0]
# max_value = 상장재무[inf_col].replace(np.inf, np.nan).max()
# 상장재무[inf_col] = 상장재무[inf_col].replace(np.inf, max_value)

# %%
상장재무.to_csv("../data/datasets/상장_파변.csv")

# %% [markdown]
# # 비상장

# %% [markdown]
# 비상장재무

# %%
외감1 = pd.read_csv("../data/for_derived_variable/외감_손익들1.csv", encoding='cp949')
외감2 = pd.read_csv("../data/for_derived_variable/외감_손익들2.csv", encoding='cp949')
외감3 = pd.read_csv("../data/for_derived_variable/외감_손익들3.csv", encoding='cp949')
외감4 = pd.read_csv("../data/for_derived_variable/외감_손익들4.csv", encoding='cp949')
외감5 = pd.read_csv("../data/for_derived_variable/외감_손익들5.csv", encoding='cp949')
외감6 = pd.read_csv("../data/for_derived_variable/외감_손익들6.csv", encoding='cp949')
외감7 = pd.read_csv("../data/for_derived_variable/외감_손익들7.csv", encoding='cp949')
외감8 = pd.read_csv("../data/for_derived_variable/외감_손익들8.csv", encoding='cp949')
외감9 = pd.read_csv("../data/for_derived_variable/외감_손익들9.csv", encoding='cp949')
외감10 = pd.read_csv("../data/for_derived_variable/외감_손익들10.csv", encoding='cp949')
외감11 = pd.read_csv("../data/for_derived_variable/외감_손익들11.csv", encoding='cp949')

# %%
비상재무 = pd.concat([외감1, 외감2, 외감3, 외감4, 외감5, 외감6, 외감7, 외감8, 외감9, 외감10, 외감11], axis=0, ignore_index=True)

# %% [markdown]
# ## describe

# %% [markdown]
# 비상재무

# %%
비상재무
# Out:
#              회사명  거래소코드     회계년도  [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)  \
# 0        (유)가든주류  97082  2019/12                                    NaN
# 1        (유)가든주류  97082  2020/12                                    NaN
# 2        (유)가든주류  97082  2021/12                                    NaN
# 3        (유)가든주류  97082  2022/12                                    NaN
# 4       (유)기흥모터스  94470  2019/12                                    NaN
# ...          ...    ...      ...                                    ...
# 243657  힐링홈스주식회사  84799  2017/12                                    NaN
# 243658  힐링홈스주식회사  84799  2018/12                                    NaN
# 243659  힐중공업주식회사  82007  2016/12                                    NaN
# 243660  힐중공업주식회사  82007  2017/12                                    NaN
# 243661  힐중공업주식회사  82007  2018/12                                    NaN
#
#         [U01B200000000]매출원가(*)(IFRS연결)(천원)  \
# 0                                      NaN
# ...

# %%
상장재무.describe()
# Out:
#            거래소코드  [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)  \
# count   8662.000                               5833.000
# mean  128435.927                           70438449.893
# std   126761.458                           93645297.763
# min       40.000                                  0.000
# 25%    45520.000                           27313009.000
# 50%    91580.000                           50073204.000
# 75%   199290.000                           85313471.000
# max   950220.000                         2932001440.000
#
#        [U01B200000000]매출원가(*)(IFRS연결)(천원)  \
# count                            5833.000
# mean                         51776401.280
# std                          69886408.084
# min                                 0.000
# 25%                          16985797.000
# 50%                          35402377.000
# 75%                          63656866.000
# max                        1539006778.000
#
#        [U01B201014400]매출총이익(손실)(IFRS연결)(천원)  \
# ...

# %%
비상재무.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[U01B100000000]매출액(수익)(*)(IFRS연결)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS연결)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS연결)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)',
#        '[U01B750000000]법인세비용(IFRS연결)(천원)',
#        '[U01B100000000]매출액(수익)(*)(IFRS)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)',
#        '[U01B750000000]법인세비용(IFRS)(천원)', '[U01210000]매출액(영업수익)(*)(천원)',
#        '[U01220010]매출원가(*)(천원)', '[U01221340]매출총이익(손실)(천원)',
#        '[U01222170]판매비와관리비(영업비용)(*)(천원)', '[U01230000]영업이익(손실)(천원)',
#        '[U01290000]법인세비용차감전(계속사업)손익(천원)', '[U01290100](계속사업손익)법인세비용(천원)'],
#       dtype='object')

# %%
len(비상재무.columns)
# Out:
# 24

# %%
비상재무.isnull().sum().sort_values(ascending=False) / len(상장재무) * 100
# Out:
# [U01B750000000]법인세비용(IFRS연결)(천원)               2781.378
# [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)          2781.378
# [U01B200000000]매출원가(*)(IFRS연결)(천원)             2781.378
# [U01B201014400]매출총이익(손실)(IFRS연결)(천원)           2781.378
# [U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)   2781.378
# [U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)    2781.378
# [U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)     2781.378
# [U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)     2696.156
# [U01B750000000]법인세비용(IFRS)(천원)                 2696.156
# [U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)       2696.156
# [U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)      2696.156
# [U01B201014400]매출총이익(손실)(IFRS)(천원)             2696.156
# [U01B200000000]매출원가(*)(IFRS)(천원)               2696.156
# [U01B100000000]매출액(수익)(*)(IFRS)(천원)            2696.156
# [U01230000]영업이익(손실)(천원)                           0.485
# [U01221340]매출총이익(손실)(천원)                          0.485
# [U01290000]법인세비용차감전(계속사업)손익(천원)                   0.485
# ...

# %%
비상재무.isin([0]).sum().sort_values(ascending=False)
# Out:
# [U01290100](계속사업손익)법인세비용(천원)                    82577
# [U01220010]매출원가(*)(천원)                          46080
# [U01210000]매출액(영업수익)(*)(천원)                     13806
# [U01221340]매출총이익(손실)(천원)                        13717
# [U01B750000000]법인세비용(IFRS)(천원)                   2434
# [U01B200000000]매출원가(*)(IFRS)(천원)                 2025
# [U01B100000000]매출액(수익)(*)(IFRS)(천원)               534
# [U01B200000000]매출원가(*)(IFRS연결)(천원)                531
# [U01B201014400]매출총이익(손실)(IFRS)(천원)                526
# [U01222170]판매비와관리비(영업비용)(*)(천원)                   462
# [U01B750000000]법인세비용(IFRS연결)(천원)                  431
# [U01230000]영업이익(손실)(천원)                           258
# [U01290000]법인세비용차감전(계속사업)손익(천원)                   152
# [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)              53
# [U01B201014400]매출총이익(손실)(IFRS연결)(천원)               50
# [U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)         12
# [U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)          12
# ...

# %%
비상재무.isin([np.inf]).sum().sort_values(ascending=False)
# Out:
# 회사명                                             0
# 거래소코드                                           0
# [U01290000]법인세비용차감전(계속사업)손익(천원)                 0
# [U01230000]영업이익(손실)(천원)                         0
# [U01222170]판매비와관리비(영업비용)(*)(천원)                 0
# [U01221340]매출총이익(손실)(천원)                        0
# [U01220010]매출원가(*)(천원)                          0
# [U01210000]매출액(영업수익)(*)(천원)                     0
# [U01B750000000]법인세비용(IFRS)(천원)                  0
# [U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)        0
# [U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)       0
# [U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)      0
# [U01B201014400]매출총이익(손실)(IFRS)(천원)              0
# [U01B200000000]매출원가(*)(IFRS)(천원)                0
# [U01B100000000]매출액(수익)(*)(IFRS)(천원)             0
# [U01B750000000]법인세비용(IFRS연결)(천원)                0
# [U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)      0
# [U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)     0
# [U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)    0
# ...

# %%
len(비상재무.index)
# Out:
# 243662

# %% [markdown]
# 전처리?

# %%
비상재무.replace(0, np.nan, inplace=True)

# %% [markdown]
# - 법인세 변화율 log_diff

# %%
비상재무['log_diff'] = pd.Series(dtype=float)  # Creating an empty Series to store log_diff values

for i in range(1, len(비상재무.index)):
    if 비상재무['거래소코드'].loc[i] == 비상재무['거래소코드'].loc[i - 1]:
        비상재무['log_diff'].loc[i] = np.log(비상재무['[U01B750000000]법인세비용(IFRS연결)(천원)'].loc[i]) - np.log(비상재무['[U01B750000000]법인세비용(IFRS연결)(천원)'].loc[i - 1])
    else:
        비상재무['log_diff'].loc[i] = np.nan

# %%
비상재무['log_diff2'] = pd.Series(dtype=float)  # Creating an empty Series to store log_diff values

for i in range(1, len(비상재무.index)):
    if 비상재무['거래소코드'].loc[i] == 비상재무['거래소코드'].loc[i - 1]:
        비상재무['log_diff2'].loc[i] = np.log(비상재무['[U01B750000000]법인세비용(IFRS)(천원)'].loc[i]) - np.log(비상재무['[U01B750000000]법인세비용(IFRS)(천원)'].loc[i - 1])
    else:
        비상재무['log_diff2'].loc[i] = np.nan

# %%
비상재무['log_diff3'] = pd.Series(dtype=float)  # Creating an empty Series to store log_diff values

for i in range(1, len(비상재무.index)):
    if 비상재무['거래소코드'].loc[i] == 비상재무['거래소코드'].loc[i - 1]:
        비상재무['log_diff3'].loc[i] = np.log(비상재무['[U01290100](계속사업손익)법인세비용(천원)'].loc[i]) - np.log(비상재무['[U01290100](계속사업손익)법인세비용(천원)'].loc[i - 1])
    else:
        비상재무['log_diff3'].loc[i] = np.nan

# %%
비상재무['log_diff'].fillna(비상재무['log_diff2']).fillna(비상재무['log_diff3'], inplace=True)
비상재무.drop(
    labels=[
        '[U01B750000000]법인세비용(IFRS연결)(천원)',
        '[U01B750000000]법인세비용(IFRS)(천원)',        
        '[U01290100](계속사업손익)법인세비용(천원)',
        'log_diff2', 'log_diff3'
    ],
    axis=1,
    inplace=True
)

# %%
비상재무.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '[U01B100000000]매출액(수익)(*)(IFRS연결)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS연결)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS연결)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)',
#        '[U01B100000000]매출액(수익)(*)(IFRS)(천원)',
#        '[U01B200000000]매출원가(*)(IFRS)(천원)',
#        '[U01B201014400]매출총이익(손실)(IFRS)(천원)',
#        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)',
#        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)',
#        '[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)',
#        '[U01210000]매출액(영업수익)(*)(천원)', '[U01220010]매출원가(*)(천원)',
#        '[U01221340]매출총이익(손실)(천원)', '[U01222170]판매비와관리비(영업비용)(*)(천원)',
#        '[U01230000]영업이익(손실)(천원)', '[U01290000]법인세비용차감전(계속사업)손익(천원)',
#        'log_diff'],
#       dtype='object')

# %%
비상재무['log_diff'].isna().sum() / len(비상재무['log_diff'])
# Out:
# 0.9968439888041631

# %% [markdown]
# - 영업레버리지 = 매출총이익 / 영업이익

# %%
비상국제연결영업이익 = 비상재무['[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)'].fillna(비상재무['[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)'])
비상국제연결영업레버리지 = 비상재무['[U01B201014400]매출총이익(손실)(IFRS연결)(천원)'] / 상장국제연결영업이익
비상국제개별영업이익 = 비상재무['[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)'].fillna(비상재무['[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)'])
비상국제개별영업레버리지 = 비상재무['[U01B201014400]매출총이익(손실)(IFRS)(천원)'] / 비상국제개별영업이익
비상일반개별영업이익 = 비상재무['[U01230000]영업이익(손실)(천원)']
비상일반개별영업레버리지 = 비상재무['[U01221340]매출총이익(손실)(천원)'] / 비상일반개별영업이익
비상영업레버리지 = 비상국제연결영업레버리지.fillna(비상국제개별영업레버리지)
비상영업레버리지 = 비상영업레버리지.fillna(비상일반개별영업레버리지)

# %%
비상재무['영업레버리지'] = 비상영업레버리지

# %%
비상재무.isna().sum()
# Out:
# 회사명                                                0
# 거래소코드                                              0
# 회계년도                                               0
# [U01B100000000]매출액(수익)(*)(IFRS연결)(천원)         240976
# [U01B200000000]매출원가(*)(IFRS연결)(천원)            241454
# [U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)    240924
# [U01B100000000]매출액(수익)(*)(IFRS)(천원)           234075
# [U01B200000000]매출원가(*)(IFRS)(천원)              235566
# [U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)      233552
# [U01210000]매출액(영업수익)(*)(천원)                    13848
# [U01220010]매출원가(*)(천원)                         46122
# [U01222170]판매비와관리비(영업비용)(*)(천원)                  504
# [U01290000]법인세비용차감전(계속사업)손익(천원)                  194
# log_diff                                      242893
# 영업레버리지                                         13780
# dtype: int64

# %%
비상재무['영업레버리지'].isin([np.inf]).sum()
# Out:
# 0

# %%
# 상장매출총이익 = 상장재무['[U01B201014400]매출총이익(손실)(IFRS연결)(천원)'].fillna(상장재무['[U01B201014400]매출총이익(손실)(IFRS)(천원)'])
# 상장매출총이익 = 상장매출총이익.fillna(상장재무['[U01221340]매출총이익(손실)(연결)(천원)'])
# 상장매출총이익 = 상장매출총이익.fillna(상장재무['[U01221340]매출총이익(손실)(천원)'])
# 상장매출총이익 = 상장매출총이익.fillna(상장재무['상장매출액'] - 상장재무['상장매출원가'])
# 상장재무['상장매출총이익'] = 상장매출총이익
비상재무.drop(
    labels=
    [
        '[U01B201014400]매출총이익(손실)(IFRS연결)(천원)',
        '[U01B201014400]매출총이익(손실)(IFRS)(천원)',        
        '[U01221340]매출총이익(손실)(천원)',
        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS연결)(천원)',
        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS연결)(천원)',
        '[U01B430000000]* (정상)영업손익(계산수치)(IFRS)(천원)',
        '[U01B420000000]* (정상)영업손익(보고서기재)(IFRS)(천원)',        
        '[U01230000]영업이익(손실)(천원)'
    ],
    axis=1,
    inplace=True
)
# print(상장매출총이익.isna().value_counts())
# 상장재무['상장매출총이익'].describe()

# %% [markdown]
# - 재무레버리지 = 영업이익 / 세전이익

# %%
비상국제연결재무레버리지 = 비상국제연결영업이익 / 비상재무['[U01B700000000]법인세비용차감전순이익(손실)(IFRS연결)(천원)']
비상국제개별재무레버리지 = 비상국제개별영업이익 / 비상재무['[U01B700000000]법인세비용차감전순이익(손실)(IFRS)(천원)']
비상일반개별재무레버리지 = 비상일반개별영업이익 / 비상재무['[U01290000]법인세비용차감전(계속사업)손익(천원)']
비상재무레버리지 = 비상국제연결재무레버리지.fillna(비상국제개별재무레버리지)
비상재무레버리지 = 비상재무레버리지.fillna(비상일반개별재무레버리지)
비상재무['재무레버리지'] = 비상재무레버리지

# %% [markdown]
# ## to_csv

# %%
비상재무 = 비상재무[['회사명', '거래소코드', '회계년도', 'log_diff', '영업레버리지', '재무레버리지']]

# %%
비상재무.isin([np.inf]).sum().sort_values(ascending=False)
# .index[0]
# Out:
# 회사명         0
# 거래소코드       0
# 회계년도        0
# log_diff    0
# 영업레버리지      0
# 재무레버리지      0
# dtype: int64

# %%
비상재무['log_diff'].value_counts().sort_index(ascending=False)
# Out:
# log_diff
# 7.826     1
# 5.154     1
# 5.056     1
# 4.973     1
# 4.534     1
#          ..
# -5.036    1
# -5.544    1
# -5.780    1
# -5.891    1
# -6.448    1
# Name: count, Length: 767, dtype: int64

# %%
비상재무.to_csv("../data/datasets/외감_파변.csv")
